# %% [markdown]
# <a href="https://colab.research.google.com/github/Mansi1321/davis_training/blob/main/menudriven.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from threed_figures import *

while True:
    print("\n--- Select Figure ---")
    print("1. Cube")
    print("2. Cuboid")
    print("3. Cylinder")
    print("4. Cone")
    print("5. Sphere")
    print("6. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 6:
        break

    print("\n--- Select Operation ---")
    print("1. Curved Surface Area (CSA)")
    print("2. Total Surface Area (TSA)")
    print("3. Volume")

    op = int(input("Enter operation: "))

    if choice == 1:  # Cube
        a = float(input("Enter side: "))
        if op == 1:
            print("CSA:", cube_csa(a))
        elif op == 2:
            print("TSA:", cube_tsa(a))
        elif op == 3:
            print("Volume:", cube_volume(a))

    elif choice == 2:  # Cuboid
        l = float(input("Enter length: "))
        b = float(input("Enter breadth: "))
        h = float(input("Enter height: "))
        if op == 1:
            print("CSA:", cuboid_csa(l, b, h))
        elif op == 2:
            print("TSA:", cuboid_tsa(l, b, h))
        elif op == 3:
            print("Volume:", cuboid_volume(l, b, h))

    elif choice == 3:  # Cylinder
        r = float(input("Enter radius: "))
        h = float(input("Enter height: "))
        if op == 1:
            print("CSA:", cylinder_csa(r, h))
        elif op == 2:
            print("TSA:", cylinder_tsa(r, h))
        elif op == 3:
            print("Volume:", cylinder_volume(r, h))

    elif choice == 4:  # Cone
        r = float(input("Enter radius: "))
        l = float(input("Enter slant height: "))
        h = float(input("Enter height: "))
        if op == 1:
            print("CSA:", cone_csa(r, l))
        elif op == 2:
            print("TSA:", cone_tsa(r, l))
        elif op == 3:
            print("Volume:", cone_volume(r, h))

    elif choice == 5:  # Sphere
        r = float(input("Enter radius: "))
        if op == 1:
            print("CSA:", sphere_csa(r))
        elif op == 2:
            print("TSA:", sphere_tsa(r))
        elif op == 3:
            print("Volume:", sphere_volume(r))

    else:
        print("Invalid choice!")
