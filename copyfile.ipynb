# %% [markdown]
# <a href="https://colab.research.google.com/github/Mansi1321/davis_training/blob/main/copyfile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to copy content from one file to another

# taking file names from user
source_file = input("Enter source file name: ")
destination_file = input("Enter destination file name: ")

try:
    with open(source_file, "r") as s, open(destination_file, "w") as d:
        for line in s:
            d.write(line)

    print("File copied successfully!")

except FileNotFoundError:
    print("Source file not found!")
except Exception as e:
    print("Error:", e)
# Out:
# Enter source file name: "input.txt"
# Enter destination file name: "output.txt"
# Source file not found!
