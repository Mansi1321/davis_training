# %% [markdown]
# <a href="https://colab.research.google.com/github/Mansi1321/davis_training/blob/main/file_write.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
filev=open("firstfile.txt","w")
print("Enter any 20 sentences:")
for x in range(20):
  sentence=input()
  filev.write(sentence+"\n")
filev.close()
# Out:
# Enter any 20 sentences:
